# %% [markdown]
# # Challenge
#
# Using this credit card fraud dataset, develop an algorithm to predict fraud. Prioritize correctly finding fraud rather than correctly labeling non-fraudulent transactions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import recall_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn import ensemble
# %matplotlib inline

# %% [markdown]
# Import the data and look at the columns.

# %%
raw = pd.read_csv('creditcard.csv')
print(raw.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Let's see what kind of data we are working with, and how many are in each Class.

# %%
print(raw['Class'].value_counts())
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We are working with serious class imbalance here -- there are many more legitimate transactions than fraudulent transactions. This might make it difficult to classify the fraudulent transactions.<br><br>
#
# Convert all to numeric and define X features and Y output.

# %%
raw = raw.apply(pd.to_numeric, errors="coerce")

# %%
X = raw.drop('Class', axis=1)
Y = raw['Class']

# %% [markdown]
# We want to maximize the number of true positives, aka the number of accurately predicted fraudulent transactions. We should also minimize the number of false negatives, or the number of fraudulent transactions that we missed. This means we should be measuring recall (TP/TP + FN).

# %% [markdown]
# Let's split our data into training and validation groups.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=77)

# %%
print(Y_train.value_counts())
print(Y_test.value_counts())
# Out:
# 0    227451
# 1       394
# Name: Class, dtype: int64
# 0    56864
# 1       98
# Name: Class, dtype: int64

# %% [markdown]
# Each class is being represented proportionately.<br>
#
# Now, train an initial model so we can evaluate different scoring techniques on that model.

# %%
neighbors = KNeighborsClassifier(n_neighbors=5)
neighbors.fit(X_train,Y_train)
Y_pred = neighbors.predict(X_train)

crosstab = pd.crosstab(Y_train, Y_pred)
print(crosstab)

macro = recall_score(Y_train, Y_pred, average='macro')
micro = recall_score(Y_train, Y_pred, average='micro')
weighted = recall_score(Y_train, Y_pred, average='weighted')
binary = recall_score(Y_train, Y_pred, average='binary')
raw = recall_score(Y_train, Y_pred, average=None)

print(f'\nMacro Recall Score: {macro}')
print(f'Micro Recall Score: {micro}')
print(f'Weighted Recall Score: {weighted}')
print(f'Binary Recall Score: {binary}')
print(f'Raw Recall Scores: {raw}')
# Out:
# col_0       0   1
# Class
# 0      227451   0
# 1         352  42
#
# Macro Recall Score: 0.5532994923857868
# Micro Recall Score: 0.9984550900831706
# Weighted Recall Score: 0.9984550900831706
# Binary Recall Score: 0.1065989847715736
# Raw Recall Scores: [ 1.          0.10659898]

# %% [markdown]
# Macro is a parameter that calculates metrics for each label, and finds their unweighted mean. This does not take label imbalance into account. This means that each label has an equal effect on the final score, so positive and negative recall are weighted the same.<br>
#
# Using "weighted" calculates metrics for each label, and finds their average weighted by support (the number of true instances for each label). This is similar to the 'macro' style, but accounts for label imbalance. This means that the more common outcome dominates the score, which falsely leads us to believe the score is near perfect.<br>
#
# Binary score only reports results for the positive class, which is the class we care about here. However, it is less convenient to employ binary weighting specifically within the cross-validation (scoring=recall_macro exists but scoring=recall_binary does not.)<br>
#
# We will continue using the macro scoring metric.

# %%
def run_score(model, X_train, Y_train, X_test, Y_test, score_type):
    
    Y_pred = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    cm = pd.crosstab(Y_test, Y_pred_test)
    
    train = recall_score(Y_train, Y_pred, average=score_type)
    validation = recall_score(Y_test, Y_pred_test, average=score_type)
    binary = recall_score(Y_train, Y_pred, average='binary')
    test = cross_val_score(model, X_train, Y_train, cv=5, scoring = 'recall_macro').mean()
    
    print(f'Training Score: {train}')
    print(f'Cross-Val Testing Score: {test}')
    print(cm)
    print(f'Validation Score: {validation} \n\n\n')

    results = {'Training Score':train, 'Cross-Val Testing Score':test, 'Validation Score':validation}
    
    return results

# %%
runs = []

def run_neighbors(num):

    print(f'n_neighbors = {num}')
    
    neighbors = KNeighborsClassifier(n_neighbors = num)
    neighbors.fit(X_train,Y_train)

    results = run_score(neighbors, X_train, Y_train, X_test, Y_test)
    results['K'] = num
    
    runs.append(results)
    
nums = {1,5,15,50,100}

for num in nums:
    run_neighbors(num)
    
runs.sort(key = lambda run: run['Validation Score'])
print(f'Best Run: {runs[-1]}')
# Out:
# n_neighbors = 1
# Training Score: 1.0
#
# Cross-Val Testing Score: 0.5848103860280839
#
# col_0      0   1
# Class
# 0      56837  27
# 1         77  21
# Validation Score: 0.6069054485891149
#
#
#
# n_neighbors = 100
# Training Score: 0.5
#
# Cross-Val Testing Score: 0.5
#
# col_0      0
# Class
# 0      56864
# 1         98
# Validation Score: 0.5
#
#
#
# n_neighbors = 5
# Training Score: 0.5532994923857868
#
# Cross-Val Testing Score: 0.5190154021959593
#
# col_0      0  1
# Class
# 0      56864  0
# 1         93  5
# Validation Score: 0.5255102040816326
#
#
#
# n_neighbors = 15
# Training Score: 0.5063451776649747
#
# Cross-Val Testing Score: 0.5025641025641026
#
# col_0      0  1
# Class
# 0      56864  0
# 1         97  1
# Validation Score: 0.5051020408163265
#
#
#
# n_neighbors = 50
# Training Score: 0.5
#
# Cross-Val Testing Score: 0.5
#
# col_0      0
# Class
# 0      56864
# 1         98
# Validation Score: 0.5
#
#
#
# Best Run: {'Training Score': 1.0, 'Cross-Val Testing Score': 0.58481038602808388, 'Validation Score': 0.60690544858911488, 'K': 1}

# %% [markdown]
# Using K-nearest neighbors with k values of 1, 5, 15, 50, and 100, we were only able to obtain a validation score of **0.607**. This was using 1 neighbor, and the score was significantly higher than validation scores using more neighbors.

# %%
runs = []

def run_logistic(alpha, pen):
    
    print(f'C = {alpha}\n')
    
    lr = LogisticRegression(C = alpha, penalty = pen)
    fit = lr.fit(X_train, Y_train)

    results = run_score(fit, X_train, Y_train, X_test, Y_test)
    results['Lambda'] = alpha
    
    runs.append(results)
    
alpha_nums = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 1, 100, 1000, 1e5, 1e7, 1e9]

for alpha in alpha_nums:
    run_logistic(alpha, 'l1')
        
runs.sort(key = lambda run: run['Validation Score'])
print(f'Best Run: {runs[-1]}')
# Out:
# C = 0.0001
#
# Training Score: 0.5
# Cross-Val Testing Score: 0.5
# col_0      0
# Class
# 0      56864
# 1         98
# Validation Score: 0.5
#
#
#
# C = 0.001
#
# Training Score: 0.6800667525935803
# Cross-Val Testing Score: 0.6546211782252276
# col_0      0   1
# Class
# 0      56849  15
# 1         64  34
# Validation Score: 0.6733374941141341
#
#
#
# C = 0.01
#
# Training Score: 0.7892807480796835
# Cross-Val Testing Score: 0.782993698798742
# col_0      0   1
# Class
# 0      56854  10
# 1         41  57
# Validation Score: 0.7907283974366337
#
#
#
# C = 0.1
#
# Training Score: 0.8171973315298993
# Cross-Val Testing Score: 0.8134317647671374
# col_0      0   1
# Class
# 0      56853  11
# 1         37  61
# Validation Score: 0.8111277677925419
#
#
#
# C = 0.3
#
# Training Score: 0.8209978433018663
# Cross-Val Testing Score: 0.8184766291237995
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
# C = 0.5
#
# Training Score: 0.8222646805591887
# Cross-Val Testing Score: 0.8172064097683144
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
# C = 1
#
# Training Score: 0.8235337160921836
# Cross-Val Testing Score: 0.8197542838351758
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
# C = 100
#
# Training Score: 0.8260717871581734
# Cross-Val Testing Score: 0.8197520855498382
# col_0      0   1
# Class
# 0      56850  14
# 1         35  63
# Validation Score: 0.8213054706970013
#
#
#
# C = 1000
#
# Training Score: 0.8260717871581734
# Cross-Val Testing Score: 0.8210179083346484
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
# C = 100000.0
#
# Training Score: 0.8248027516251785
# Cross-Val Testing Score: 0.8197520855498382
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
# C = 10000000.0
#
# Training Score: 0.8235337160921836
# Cross-Val Testing Score: 0.8210179083346484
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
# C = 1000000000.0
#
# Training Score: 0.8248027516251785
# Cross-Val Testing Score: 0.8197520855498382
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
# Best Run: {'Training Score': 0.82480275162517847, 'Cross-Val Testing Score': 0.81975208554983825, 'Validation Score': 0.82131426360639925, 'Lambda': 1000000000.0, 'Score Type': 'macro'}

# %% [markdown]
# The best macro recall score using Lasso regression was a validation score of **0.821**. This was achieved without regularization, lambda was 1e9.

# %%
runs = []
for alpha in alpha_nums:
    run_logistic(alpha, 'l2')
        
runs.sort(key = lambda run: run['Validation Score'])
print(f'Best Run: {runs[-1]}')
# Out:
# C = 0.0001
#
# Training Score: 0.647063035633022
# Cross-Val Testing Score: 0.6317689324167493
# col_0      0   1
# Class
# 0      56847  17
# 1         77  21
# Validation Score: 0.6069933776830935
#
#
#
# C = 0.001
#
# Training Score: 0.7485792834455982
# Cross-Val Testing Score: 0.7459876175962858
# col_0      0   1
# Class
# 0      56845  19
# 1         49  49
# Validation Score: 0.7498329347214406
#
#
#
# C = 0.01
#
# Training Score: 0.8259926492339612
# Cross-Val Testing Score: 0.8070400647657154
# col_0      0   1
# Class
# 0      56844  20
# 1         34  64
# Validation Score: 0.8263547540569407
#
#
#
# C = 0.1
#
# Training Score: 0.8310907741226665
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56848  16
# 1         32  66
# Validation Score: 0.8365940073271851
#
#
#
# C = 0.3
#
# Training Score: 0.8285988668458004
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56850  14
# 1         31  67
# Validation Score: 0.8417136339623075
#
#
#
# C = 0.5
#
# Training Score: 0.8387489528340872
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56851  13
# 1         30  68
# Validation Score: 0.8468244676880319
#
#
#
# C = 1
#
# Training Score: 0.8209868519235035
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56851  13
# 1         33  65
# Validation Score: 0.8315183452390522
#
#
#
# C = 100
#
# Training Score: 0.8133440611417906
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56844  20
# 1         33  65
# Validation Score: 0.8314567948732672
#
#
#
# C = 1000
#
# Training Score: 0.8133462594174632
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56844  20
# 1         33  65
# Validation Score: 0.8314567948732672
#
#
#
# C = 100000.0
#
# Training Score: 0.8133462594174632
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56844  20
# 1         33  65
# Validation Score: 0.8314567948732672
#
#
#
# C = 10000000.0
#
# Training Score: 0.8133440611417906
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56844  20
# 1         33  65
# Validation Score: 0.8314567948732672
#
#
#
# C = 1000000000.0
#
# Training Score: 0.8209846536478309
# Cross-Val Testing Score: 0.8083199177624291
# col_0      0   1
# Class
# 0      56851  13
# 1         33  65
# Validation Score: 0.8315183452390522
#
#
#
# Best Run: {'Training Score': 0.83874895283408724, 'Cross-Val Testing Score': 0.80831991776242906, 'Validation Score': 0.84682446768803188, 'Lambda': 0.5, 'Score Type': 'macro'}

# %% [markdown]
# The best score using Ridge regression was a validation score of **0.847**. This was achieved with moderate regularization, lambda was 0.5. This is slightly better than the Lasso score of 0.821, so going forward I would choose ridge over lasso.

# %%
runs = []

def run_tree (depth_max, random, feature_max, min_split, score_type):

    print(f'Max Depth: {depth_max}, Random State = {random}, Max Feature = {feature_max}, Min Samples Split = {min_split}')
    
    decision_tree = tree.DecisionTreeClassifier(
        criterion = 'entropy',
        max_depth = depth_max,
        random_state = random,
        max_features = feature_max,
        min_samples_split = min_split
    )
    decision_tree.fit(X_train, Y_train)
    
    results = run_score(decision_tree, X_train, Y_train, X_test, Y_test, score_type)
    results['Max Depth'] = depth_max
    results['Random State'] = random
    results['Max Feature'] = feature_max
    results['Min Samples Split'] = min_split
    results['Score Type'] = score_type
    
    runs.append(results)
        
depth_maxs = [3,4,5]
randoms = [1]
feature_maxs = [4,5,6,7]
min_splits = [4,5,6,7]

for depth_max in depth_maxs:
    for random in randoms:
        for feature_max in feature_maxs:
            for min_split in min_splits:
                run_tree (depth_max, random, feature_max, min_split, 'macro')
                    
runs.sort(key = lambda run: run['Validation Score'])
print(f'Best Run: {runs[-1]}')
# Out:
# Max Depth: 3, Random State = 1, Max Feature = 4, Min Samples Split = 4
# Training Score: 0.8222361029754454
#
# Cross-Val Testing Score: 0.809646968984123
#
# col_0      0   1
# Class
# 0      56847  17
# 1         43  55
# Validation Score: 0.7804627654381955
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 4, Min Samples Split = 5
# Training Score: 0.8222361029754454
#
# Cross-Val Testing Score: 0.809646968984123
#
# col_0      0   1
# Class
# 0      56847  17
# 1         43  55
# Validation Score: 0.7804627654381955
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 4, Min Samples Split = 6
# Training Score: 0.8222361029754454
#
# Cross-Val Testing Score: 0.809646968984123
#
# col_0      0   1
# Class
# 0      56847  17
# 1         43  55
# Validation Score: 0.7804627654381955
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 4, Min Samples Split = 7
# Training Score: 0.8222361029754454
#
# Cross-Val Testing Score: 0.809646968984123
#
# col_0      0   1
# Class
# 0      56847  17
# 1         43  55
# Validation Score: 0.7804627654381955
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 5, Min Samples Split = 4
# Training Score: 0.8514481012667268
#
# Cross-Val Testing Score: 0.8400399054832672
#
# col_0      0   1
# Class
# 0      56848  16
# 1         35  63
# Validation Score: 0.8212878848782057
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 5, Min Samples Split = 5
# Training Score: 0.8514481012667268
#
# Cross-Val Testing Score: 0.8400399054832672
#
# col_0      0   1
# Class
# 0      56848  16
# 1         35  63
# Validation Score: 0.8212878848782057
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 5, Min Samples Split = 6
# Training Score: 0.8514481012667268
#
# Cross-Val Testing Score: 0.8400399054832672
#
# col_0      0   1
# Class
# 0      56848  16
# 1         35  63
# Validation Score: 0.8212878848782057
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 5, Min Samples Split = 7
# Training Score: 0.8514481012667268
#
# Cross-Val Testing Score: 0.8400399054832672
#
# col_0      0   1
# Class
# 0      56848  16
# 1         35  63
# Validation Score: 0.8212878848782057
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 6, Min Samples Split = 4
# Training Score: 0.8691684349395319
#
# Cross-Val Testing Score: 0.8640952583729284
#
# col_0      0   1
# Class
# 0      56837  27
# 1         35  63
# Validation Score: 0.8211911628748292
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 6, Min Samples Split = 5
# Training Score: 0.8691684349395319
#
# Cross-Val Testing Score: 0.8640952583729284
#
# col_0      0   1
# Class
# 0      56837  27
# 1         35  63
# Validation Score: 0.8211911628748292
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 6, Min Samples Split = 6
# Training Score: 0.8691684349395319
#
# Cross-Val Testing Score: 0.8640952583729284
#
# col_0      0   1
# Class
# 0      56837  27
# 1         35  63
# Validation Score: 0.8211911628748292
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 6, Min Samples Split = 7
# Training Score: 0.8691684349395319
#
# Cross-Val Testing Score: 0.8640952583729284
#
# col_0      0   1
# Class
# 0      56837  27
# 1         35  63
# Validation Score: 0.8211911628748292
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 7, Min Samples Split = 4
# Training Score: 0.8780846578055848
#
# Cross-Val Testing Score: 0.8679721880688357
#
# col_0      0   1
# Class
# 0      56849  15
# 1         31  67
# Validation Score: 0.8417048410529095
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 7, Min Samples Split = 5
# Training Score: 0.8780846578055848
#
# Cross-Val Testing Score: 0.8679721880688357
#
# col_0      0   1
# Class
# 0      56849  15
# 1         31  67
# Validation Score: 0.8417048410529095
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 7, Min Samples Split = 6
# Training Score: 0.8780846578055848
#
# Cross-Val Testing Score: 0.8679721880688357
#
# col_0      0   1
# Class
# 0      56849  15
# 1         31  67
# Validation Score: 0.8417048410529095
#
#
#
# Max Depth: 3, Random State = 1, Max Feature = 7, Min Samples Split = 7
# Training Score: 0.8780846578055848
#
# Cross-Val Testing Score: 0.8679677914981608
#
# col_0      0   1
# Class
# 0      56849  15
# 1         31  67
# Validation Score: 0.8417048410529095
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 4, Min Samples Split = 4
# Training Score: 0.8819225402639854
#
# Cross-Val Testing Score: 0.8590737346067756
#
# col_0      0   1
# Class
# 0      56850  14
# 1         30  68
# Validation Score: 0.846815674778634
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 4, Min Samples Split = 5
# Training Score: 0.8819225402639854
#
# Cross-Val Testing Score: 0.8590737346067756
#
# col_0      0   1
# Class
# 0      56850  14
# 1         30  68
# Validation Score: 0.846815674778634
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 4, Min Samples Split = 6
# Training Score: 0.8819225402639854
#
# Cross-Val Testing Score: 0.8590737346067756
#
# col_0      0   1
# Class
# 0      56850  14
# 1         30  68
# Validation Score: 0.846815674778634
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 4, Min Samples Split = 7
# Training Score: 0.8819225402639854
#
# Cross-Val Testing Score: 0.8641326292719883
#
# col_0      0   1
# Class
# 0      56850  14
# 1         30  68
# Validation Score: 0.846815674778634
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 5, Min Samples Split = 4
# Training Score: 0.8717306870379199
#
# Cross-Val Testing Score: 0.8502528672218608
#
# col_0      0   1
# Class
# 0      56844  20
# 1         31  67
# Validation Score: 0.8416608765059204
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 5, Min Samples Split = 5
# Training Score: 0.8717306870379199
#
# Cross-Val Testing Score: 0.8502528672218608
#
# col_0      0   1
# Class
# 0      56844  20
# 1         31  67
# Validation Score: 0.8416608765059204
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 5, Min Samples Split = 6
# Training Score: 0.8717306870379199
#
# Cross-Val Testing Score: 0.8502528672218608
#
# col_0      0   1
# Class
# 0      56844  20
# 1         31  67
# Validation Score: 0.8416608765059204
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 5, Min Samples Split = 7
# Training Score: 0.8717306870379199
#
# Cross-Val Testing Score: 0.8502528672218608
#
# col_0      0   1
# Class
# 0      56844  20
# 1         31  67
# Validation Score: 0.8416608765059204
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 6, Min Samples Split = 4
# Training Score: 0.8476717705271579
#
# Cross-Val Testing Score: 0.8489537470393363
#
# col_0      0   1
# Class
# 0      56853  11
# 1         34  64
# Validation Score: 0.8264338902415215
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 6, Min Samples Split = 5
# Training Score: 0.8476717705271579
#
# Cross-Val Testing Score: 0.8489537470393363
#
# col_0      0   1
# Class
# 0      56853  11
# 1         34  64
# Validation Score: 0.8264338902415215
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 6, Min Samples Split = 6
# Training Score: 0.8476717705271579
#
# Cross-Val Testing Score: 0.8489537470393363
#
# col_0      0   1
# Class
# 0      56853  11
# 1         34  64
# Validation Score: 0.8264338902415215
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 6, Min Samples Split = 7
# Training Score: 0.8476717705271579
#
# Cross-Val Testing Score: 0.8489537470393363
#
# col_0      0   1
# Class
# 0      56853  11
# 1         34  64
# Validation Score: 0.8264338902415215
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 7, Min Samples Split = 4
# Training Score: 0.8895279603592647
#
# Cross-Val Testing Score: 0.8819633509277258
#
# col_0      0   1
# Class
# 0      56849  15
# 1         30  68
# Validation Score: 0.8468068818692361
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 7, Min Samples Split = 5
# Training Score: 0.8895279603592647
#
# Cross-Val Testing Score: 0.8819633509277258
#
# col_0      0   1
# Class
# 0      56849  15
# 1         30  68
# Validation Score: 0.8468068818692361
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 7, Min Samples Split = 6
# Training Score: 0.8895279603592647
#
# Cross-Val Testing Score: 0.8819633509277258
#
# col_0      0   1
# Class
# 0      56849  15
# 1         30  68
# Validation Score: 0.8468068818692361
#
#
#
# Max Depth: 4, Random State = 1, Max Feature = 7, Min Samples Split = 7
# Training Score: 0.8895279603592647
#
# Cross-Val Testing Score: 0.8819633509277258
#
# col_0      0   1
# Class
# 0      56849  15
# 1         30  68
# Validation Score: 0.8468068818692361
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 4, Min Samples Split = 4
# Training Score: 0.8832157568293786
#
# Cross-Val Testing Score: 0.8794146365059557
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 4, Min Samples Split = 5
# Training Score: 0.8832157568293786
#
# Cross-Val Testing Score: 0.8794146365059557
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 4, Min Samples Split = 6
# Training Score: 0.8832157568293786
#
# Cross-Val Testing Score: 0.8794146365059557
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 4, Min Samples Split = 7
# Training Score: 0.8832157568293786
#
# Cross-Val Testing Score: 0.8794102399352809
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 5, Min Samples Split = 4
# Training Score: 0.8718120232378047
#
# Cross-Val Testing Score: 0.8629168494744188
#
# col_0      0   1
# Class
# 0      56857   7
# 1         34  64
# Validation Score: 0.8264690618791128
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 5, Min Samples Split = 5
# Training Score: 0.8718120232378047
#
# Cross-Val Testing Score: 0.8629168494744188
#
# col_0      0   1
# Class
# 0      56857   7
# 1         34  64
# Validation Score: 0.8264690618791128
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 5, Min Samples Split = 6
# Training Score: 0.8718120232378047
#
# Cross-Val Testing Score: 0.8629168494744188
#
# col_0      0   1
# Class
# 0      56857   7
# 1         34  64
# Validation Score: 0.8264690618791128
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 5, Min Samples Split = 7
# Training Score: 0.8718120232378047
#
# Cross-Val Testing Score: 0.8629168494744188
#
# col_0      0   1
# Class
# 0      56857   7
# 1         34  64
# Validation Score: 0.8264690618791128
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 6, Min Samples Split = 4
# Training Score: 0.8907991941679323
#
# Cross-Val Testing Score: 0.8590272472070956
#
# col_0      0   1
# Class
# 0      56855   9
# 1         26  72
# Validation Score: 0.8672678025909295
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 6, Min Samples Split = 5
# Training Score: 0.8907991941679323
#
# Cross-Val Testing Score: 0.8603071002038094
#
# col_0      0   1
# Class
# 0      56855   9
# 1         26  72
# Validation Score: 0.8672678025909295
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 6, Min Samples Split = 6
# Training Score: 0.8907991941679323
#
# Cross-Val Testing Score: 0.8603071002038094
#
# col_0      0   1
# Class
# 0      56855   9
# 1         26  72
# Validation Score: 0.8672678025909295
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 6, Min Samples Split = 7
# Training Score: 0.8907991941679323
#
# Cross-Val Testing Score: 0.8577666614928393
#
# col_0      0   1
# Class
# 0      56855   9
# 1         26  72
# Validation Score: 0.8672678025909295
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 7, Min Samples Split = 4
# Training Score: 0.9072790698914858
#
# Cross-Val Testing Score: 0.8844730138372657
#
# col_0      0   1
# Class
# 0      56845  19
# 1         33  65
# Validation Score: 0.8314655877826651
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 7, Min Samples Split = 5
# Training Score: 0.9085481054244806
#
# Cross-Val Testing Score: 0.8895687619709886
#
# col_0      0   1
# Class
# 0      56845  19
# 1         30  68
# Validation Score: 0.8467717102316448
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 7, Min Samples Split = 6
# Training Score: 0.9085481054244806
#
# Cross-Val Testing Score: 0.890841179611811
#
# col_0      0   1
# Class
# 0      56845  19
# 1         30  68
# Validation Score: 0.8467717102316448
#
#
#
# Max Depth: 5, Random State = 1, Max Feature = 7, Min Samples Split = 7
# Training Score: 0.9085481054244806
#
# Cross-Val Testing Score: 0.892098209303595
#
# col_0      0   1
# Class
# 0      56845  19
# 1         30  68
# Validation Score: 0.8467717102316448
#
#
#
# Best Run: {'Training Score': 0.8907991941679323, 'Cross-Val Testing Score': 0.85776666149283931, 'Validation Score': 0.8672678025909295, 'Max Depth': 5, 'Random State': 1, 'Max Feature': 6, 'Min Samples Split': 7, 'Score Type': 'macro'}

# %% [markdown]
# The best score using a singular decision tree was a validation score of **0.867**, which is significantly better than that of ridge and lasso regression. This was achieved with Max Depth = 5, Max Feature = 6, and Min Samples Split = 7. These were the upper limits of the parameters I set, and the score might even be better if I increased these upper limits. However, in the interest of time, I will keep them as is.

# %%
runs = []

def run_forest(depth_max, feature_max, min_split, n, random, score_type):
    
    print(f'Max Depth: {depth_max}, Max Feature = {feature_max}, Number of Trees = {n}, Random State = {random}, Min Samples Split: {min_split}')
    
    rfc = ensemble.RandomForestClassifier(
    max_depth = depth_max,
    max_features = feature_max,
    min_samples_split = min_split,
    n_estimators = n,
    random_state = random
    )

    rfc.fit(X_train,Y_train)

    results = run_score(rfc, X_train, Y_train, X_test, Y_test, score_type)
    results['Max Depth'] = depth_max
    results['Random State'] = random
    results['Max Feature'] = feature_max
    results['Number of Trees'] = n
    results['Min Samples Split'] = min_split
    
    runs.append(results)
    print("\n")
        
depth_maxs = [3,4,5]
randoms = [1]
feature_maxs = [4,5,6,7]
min_splits = [4,5,6,7]
ns = [10, 50, 100]

for depth_max in depth_maxs:
    for feature_max in feature_maxs:
        for min_split in min_splits:
            for n in ns:
                for random in randoms:
                    run_forest (depth_max, feature_max, min_split, n, random, 'macro')
                        
runs.sort(key = lambda run: run['Validation Score'])
print(f'Best Run: {runs[-1]}')
# Out:
# Max Depth: 3, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8273386244154958
#
# Cross-Val Testing Score: 0.8134716572141582
#
# col_0      0   1
# Class
# 0      56851  13
# 1         40  58
# Validation Score: 0.7958040595247666
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.812118991122247
#
# Cross-Val Testing Score: 0.7982212663781469
#
# col_0      0   1
# Class
# 0      56852  12
# 1         43  55
# Validation Score: 0.7805067299851849
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8019667068582876
#
# Cross-Val Testing Score: 0.7994892874482945
#
# col_0      0   1
# Class
# 0      56852  12
# 1         42  56
# Validation Score: 0.7856087708015114
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8273386244154958
#
# Cross-Val Testing Score: 0.8134716572141582
#
# col_0      0   1
# Class
# 0      56851  13
# 1         40  58
# Validation Score: 0.7958040595247666
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.812118991122247
#
# Cross-Val Testing Score: 0.7982212663781469
#
# col_0      0   1
# Class
# 0      56852  12
# 1         43  55
# Validation Score: 0.7805067299851849
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8019667068582876
#
# Cross-Val Testing Score: 0.7994892874482945
#
# col_0      0   1
# Class
# 0      56852  12
# 1         42  56
# Validation Score: 0.7856087708015114
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8273386244154958
#
# Cross-Val Testing Score: 0.8134716572141582
#
# col_0      0   1
# Class
# 0      56851  13
# 1         40  58
# Validation Score: 0.7958040595247666
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8108499555892521
#
# Cross-Val Testing Score: 0.7982212663781469
#
# col_0      0   1
# Class
# 0      56852  12
# 1         43  55
# Validation Score: 0.7805067299851849
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.801964508582615
#
# Cross-Val Testing Score: 0.7994892874482945
#
# col_0      0   1
# Class
# 0      56852  12
# 1         42  56
# Validation Score: 0.7856087708015114
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8273386244154958
#
# Cross-Val Testing Score: 0.8134716572141582
#
# col_0      0   1
# Class
# 0      56851  13
# 1         40  58
# Validation Score: 0.7958040595247666
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8070428489902672
#
# Cross-Val Testing Score: 0.7982374948753881
#
# col_0      0   1
# Class
# 0      56852  12
# 1         43  55
# Validation Score: 0.7805067299851849
#
#
#
#
#
# Max Depth: 3, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.801964508582615
#
# Cross-Val Testing Score: 0.7994892874482945
#
# col_0      0   1
# Class
# 0      56852  12
# 1         42  56
# Validation Score: 0.7856087708015114
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.84638295051311
#
# Cross-Val Testing Score: 0.8274045009884194
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8387621424881226
#
# Cross-Val Testing Score: 0.8273913112763948
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8362240714221327
#
# Cross-Val Testing Score: 0.8286453021346386
#
# col_0      0   1
# Class
# 0      56851  13
# 1         41  57
# Validation Score: 0.79070201870844
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.84638295051311
#
# Cross-Val Testing Score: 0.827402302703082
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8387621424881226
#
# Cross-Val Testing Score: 0.8273913112763948
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8362240714221327
#
# Cross-Val Testing Score: 0.8286453021346386
#
# col_0      0   1
# Class
# 0      56851  13
# 1         41  57
# Validation Score: 0.79070201870844
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.84638295051311
#
# Cross-Val Testing Score: 0.827402302703082
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8387621424881226
#
# Cross-Val Testing Score: 0.8273913112763948
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8349572341648105
#
# Cross-Val Testing Score: 0.8286453021346386
#
# col_0      0   1
# Class
# 0      56851  13
# 1         41  57
# Validation Score: 0.79070201870844
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8463785539617648
#
# Cross-Val Testing Score: 0.8236048343486516
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8387621424881226
#
# Cross-Val Testing Score: 0.8261254884915846
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8336860003561429
#
# Cross-Val Testing Score: 0.8273794793498285
#
# col_0      0   1
# Class
# 0      56851  13
# 1         41  57
# Validation Score: 0.79070201870844
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8615937907036685
#
# Cross-Val Testing Score: 0.8426881893187922
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8451029236017522
#
# Cross-Val Testing Score: 0.828693987626362
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8463697608590746
#
# Cross-Val Testing Score: 0.8312212366253074
#
# col_0      0   1
# Class
# 0      56851  13
# 1         37  61
# Validation Score: 0.8111101819737462
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8615937907036685
#
# Cross-Val Testing Score: 0.8426881893187922
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8438338880687573
#
# Cross-Val Testing Score: 0.828693987626362
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8463697608590746
#
# Cross-Val Testing Score: 0.828673362558446
#
# col_0      0   1
# Class
# 0      56851  13
# 1         37  61
# Validation Score: 0.8111101819737462
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8615937907036685
#
# Cross-Val Testing Score: 0.8426881893187922
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8412958170027673
#
# Cross-Val Testing Score: 0.8286961859116995
#
# col_0      0   1
# Class
# 0      56851  13
# 1         39  59
# Validation Score: 0.8009061003410931
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8463697608590746
#
# Cross-Val Testing Score: 0.8299369870579187
#
# col_0      0   1
# Class
# 0      56851  13
# 1         37  61
# Validation Score: 0.8111101819737462
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8615937907036685
#
# Cross-Val Testing Score: 0.8426881893187922
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8451029236017522
#
# Cross-Val Testing Score: 0.8286961859116995
#
# col_0      0   1
# Class
# 0      56851  13
# 1         38  60
# Validation Score: 0.8060081411574196
#
#
#
#
#
# Max Depth: 3, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8476387963920695
#
# Cross-Val Testing Score: 0.83121903833997
#
# col_0      0   1
# Class
# 0      56851  13
# 1         37  61
# Validation Score: 0.8111101819737462
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8679301752659528
#
# Cross-Val Testing Score: 0.8629303624973904
#
# col_0      0   1
# Class
# 0      56851  13
# 1         30  68
# Validation Score: 0.8468244676880319
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.860322556895001
#
# Cross-Val Testing Score: 0.843891296399975
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8539817757813715
#
# Cross-Val Testing Score: 0.8413596508303547
#
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8679301752659528
#
# Cross-Val Testing Score: 0.8629303624973904
#
# col_0      0   1
# Class
# 0      56851  13
# 1         30  68
# Validation Score: 0.8468244676880319
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.860322556895001
#
# Cross-Val Testing Score: 0.843891296399975
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8539817757813715
#
# Cross-Val Testing Score: 0.8413596508303547
#
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8679301752659528
#
# Cross-Val Testing Score: 0.8629303624973904
#
# col_0      0   1
# Class
# 0      56851  13
# 1         30  68
# Validation Score: 0.8468244676880319
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.860322556895001
#
# Cross-Val Testing Score: 0.843891296399975
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8514437047153817
#
# Cross-Val Testing Score: 0.8426254736151648
#
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8679301752659528
#
# Cross-Val Testing Score: 0.8629303624973904
#
# col_0      0   1
# Class
# 0      56851  13
# 1         30  68
# Validation Score: 0.8468244676880319
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.860322556895001
#
# Cross-Val Testing Score: 0.843891296399975
#
# col_0      0   1
# Class
# 0      56851  13
# 1         35  63
# Validation Score: 0.8213142636063993
#
#
#
#
#
# Max Depth: 3, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8514437047153817
#
# Cross-Val Testing Score: 0.8426254736151648
#
# col_0      0   1
# Class
# 0      56851  13
# 1         36  62
# Validation Score: 0.8162122227900728
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8730370932573485
#
# Cross-Val Testing Score: 0.8261680963162281
#
# col_0      0   1
# Class
# 0      56852  12
# 1         32  66
# Validation Score: 0.8366291789647766
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8578086668614093
#
# Cross-Val Testing Score: 0.8413794353017445
#
# col_0      0   1
# Class
# 0      56853  11
# 1         35  63
# Validation Score: 0.821331849425195
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8552749923467646
#
# Cross-Val Testing Score: 0.8350362911657901
#
# col_0      0   1
# Class
# 0      56855   9
# 1         37  61
# Validation Score: 0.8111453536113375
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8730370932573485
#
# Cross-Val Testing Score: 0.824902273531418
#
# col_0      0   1
# Class
# 0      56852  12
# 1         32  66
# Validation Score: 0.8366291789647766
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8578086668614093
#
# Cross-Val Testing Score: 0.8388662165147028
#
# col_0      0   1
# Class
# 0      56853  11
# 1         35  63
# Validation Score: 0.821331849425195
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8552771906224372
#
# Cross-Val Testing Score: 0.8350525196630315
#
# col_0      0   1
# Class
# 0      56855   9
# 1         37  61
# Validation Score: 0.8111453536113375
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8705012204670312
#
# Cross-Val Testing Score: 0.8223706280101212
#
# col_0      0   1
# Class
# 0      56852  12
# 1         32  66
# Validation Score: 0.8366291789647766
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8603445396517266
#
# Cross-Val Testing Score: 0.838882445011944
#
# col_0      0   1
# Class
# 0      56853  11
# 1         35  63
# Validation Score: 0.821331849425195
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8540125516407874
#
# Cross-Val Testing Score: 0.8350362911657904
#
# col_0      0   1
# Class
# 0      56855   9
# 1         36  62
# Validation Score: 0.8162473944276641
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8705012204670312
#
# Cross-Val Testing Score: 0.8210885767280699
#
# col_0      0   1
# Class
# 0      56852  12
# 1         32  66
# Validation Score: 0.8366291789647766
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8565330365013968
#
# Cross-Val Testing Score: 0.8363021139506003
#
# col_0      0   1
# Class
# 0      56852  12
# 1         36  62
# Validation Score: 0.8162210156994706
#
#
#
#
#
# Max Depth: 4, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8476673739758127
#
# Cross-Val Testing Score: 0.8299339481760551
#
# col_0      0   1
# Class
# 0      56855   9
# 1         38  60
# Validation Score: 0.8060433127950111
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8514832736774878
#
# Cross-Val Testing Score: 0.8514757589677279
#
# col_0      0   1
# Class
# 0      56857   7
# 1         37  61
# Validation Score: 0.8111629394301334
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8502142381444928
#
# Cross-Val Testing Score: 0.8400715218812234
#
# col_0      0   1
# Class
# 0      56858   6
# 1         36  62
# Validation Score: 0.8162737731558578
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8565572175337949
#
# Cross-Val Testing Score: 0.8413351464290196
#
# col_0      0   1
# Class
# 0      56858   6
# 1         36  62
# Validation Score: 0.8162737731558578
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8514832736774878
#
# Cross-Val Testing Score: 0.8514595304704867
#
# col_0      0   1
# Class
# 0      56857   7
# 1         37  61
# Validation Score: 0.8111629394301334
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8527501109348101
#
# Cross-Val Testing Score: 0.8426031674508436
#
# col_0      0   1
# Class
# 0      56857   7
# 1         34  64
# Validation Score: 0.8264690618791128
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8565572175337949
#
# Cross-Val Testing Score: 0.8400693236442095
#
# col_0      0   1
# Class
# 0      56857   7
# 1         35  63
# Validation Score: 0.8213670210627864
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8514832736774878
#
# Cross-Val Testing Score: 0.848925686615529
#
# col_0      0   1
# Class
# 0      56857   7
# 1         37  61
# Validation Score: 0.8111629394301334
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8565572175337949
#
# Cross-Val Testing Score: 0.8426031674508436
#
# col_0      0   1
# Class
# 0      56856   8
# 1         34  64
# Validation Score: 0.826460268969715
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8540191464678051
#
# Cross-Val Testing Score: 0.8400530951469684
#
# col_0      0   1
# Class
# 0      56856   8
# 1         35  63
# Validation Score: 0.8213582281533885
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8514832736774878
#
# Cross-Val Testing Score: 0.8476620621160563
#
# col_0      0   1
# Class
# 0      56857   7
# 1         37  61
# Validation Score: 0.8111629394301334
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8565550192581224
#
# Cross-Val Testing Score: 0.8400530951469684
#
# col_0      0   1
# Class
# 0      56856   8
# 1         35  63
# Validation Score: 0.8213582281533885
#
#
#
#
#
# Max Depth: 4, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8552903802764726
#
# Cross-Val Testing Score: 0.8400508968616307
#
# col_0      0   1
# Class
# 0      56856   8
# 1         36  62
# Validation Score: 0.816256187337062
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8730414898086936
#
# Cross-Val Testing Score: 0.8603912815718788
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8768617860617136
#
# Cross-Val Testing Score: 0.8515340780040331
#
# col_0      0   1
# Class
# 0      56855   9
# 1         34  64
# Validation Score: 0.8264514760603172
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8692475728637441
#
# Cross-Val Testing Score: 0.8540538916954106
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8730414898086936
#
# Cross-Val Testing Score: 0.8578596360022586
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8755927505287188
#
# Cross-Val Testing Score: 0.8502704535045604
#
# col_0      0   1
# Class
# 0      56855   9
# 1         34  64
# Validation Score: 0.8264514760603172
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8679785373307491
#
# Cross-Val Testing Score: 0.8540538916954106
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8730414898086936
#
# Cross-Val Testing Score: 0.86293915563874
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8743237149957238
#
# Cross-Val Testing Score: 0.8502704535045604
#
# col_0      0   1
# Class
# 0      56855   9
# 1         34  64
# Validation Score: 0.8264514760603172
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8679785373307491
#
# Cross-Val Testing Score: 0.8540679219073143
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8730414898086936
#
# Cross-Val Testing Score: 0.8667624861316405
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8743237149957238
#
# Cross-Val Testing Score: 0.8566135976405148
#
# col_0      0   1
# Class
# 0      56855   9
# 1         34  64
# Validation Score: 0.8264514760603172
#
#
#
#
#
# Max Depth: 4, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8692475728637441
#
# Cross-Val Testing Score: 0.8528020991225042
#
# col_0      0   1
# Class
# 0      56855   9
# 1         32  66
# Validation Score: 0.8366555576929702
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8832025671753432
#
# Cross-Val Testing Score: 0.865528279696463
#
# col_0      0   1
# Class
# 0      56858   6
# 1         33  65
# Validation Score: 0.8315798956048372
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8819379281936934
#
# Cross-Val Testing Score: 0.8667726368651545
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8806666943850259
#
# Cross-Val Testing Score: 0.8617159406785735
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.883198170623998
#
# Cross-Val Testing Score: 0.865528279696463
#
# col_0      0   1
# Class
# 0      56858   6
# 1         27  71
# Validation Score: 0.8621921405027966
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8819335316423482
#
# Cross-Val Testing Score: 0.8667726368651545
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8755905522530463
#
# Cross-Val Testing Score: 0.8629773668927087
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.883198170623998
#
# Cross-Val Testing Score: 0.8655260814111255
#
# col_0      0   1
# Class
# 0      56858   6
# 1         27  71
# Validation Score: 0.8621921405027966
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8806666943850259
#
# Cross-Val Testing Score: 0.8667748351504919
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8768573895103686
#
# Cross-Val Testing Score: 0.8604316911111847
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8819291350910031
#
# Cross-Val Testing Score: 0.865528279696463
#
# col_0      0   1
# Class
# 0      56858   6
# 1         27  71
# Validation Score: 0.8621921405027966
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8819379281936934
#
# Cross-Val Testing Score: 0.8629839616520739
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 4, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8781264250433636
#
# Cross-Val Testing Score: 0.8617299708904771
#
# col_0      0   1
# Class
# 0      56855   9
# 1         31  67
# Validation Score: 0.8417575985092968
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8730590760140741
#
# Cross-Val Testing Score: 0.8515095736510213
#
# col_0      0   1
# Class
# 0      56858   6
# 1         37  61
# Validation Score: 0.8111717323395312
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8717878422054066
#
# Cross-Val Testing Score: 0.8591281742130146
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8755949488043914
#
# Cross-Val Testing Score: 0.8591444027102559
#
# col_0      0   1
# Class
# 0      56858   6
# 1         31  67
# Validation Score: 0.8417839772374904
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.867985132157767
#
# Cross-Val Testing Score: 0.8451295759499098
#
# col_0      0   1
# Class
# 0      56858   6
# 1         36  62
# Validation Score: 0.8162737731558578
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.873054679462729
#
# Cross-Val Testing Score: 0.8553122790760057
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8730568777384016
#
# Cross-Val Testing Score: 0.8565965286433943
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8616399544927923
#
# Cross-Val Testing Score: 0.8438637531650997
#
# col_0      0   1
# Class
# 0      56858   6
# 1         36  62
# Validation Score: 0.8162737731558578
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8692475728637441
#
# Cross-Val Testing Score: 0.856594330358057
#
# col_0      0   1
# Class
# 0      56858   6
# 1         33  65
# Validation Score: 0.8315798956048372
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8717878422054066
#
# Cross-Val Testing Score: 0.8552960505787646
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8629089900257871
#
# Cross-Val Testing Score: 0.8426325856117858
#
# col_0      0   1
# Class
# 0      56858   6
# 1         37  61
# Validation Score: 0.8111717323395312
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8654404662647593
#
# Cross-Val Testing Score: 0.8540464562911956
#
# col_0      0   1
# Class
# 0      56858   6
# 1         34  64
# Validation Score: 0.8264778547885108
#
#
#
#
#
# Max Depth: 5, Max Feature = 4, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8717878422054066
#
# Cross-Val Testing Score: 0.8578785799254458
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8882875024100132
#
# Cross-Val Testing Score: 0.8667489731569924
#
# col_0      0   1
# Class
# 0      56857   7
# 1         29  69
# Validation Score: 0.8519792659607456
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8794042536790487
#
# Cross-Val Testing Score: 0.8566171537113105
#
# col_0      0   1
# Class
# 0      56858   6
# 1         33  65
# Validation Score: 0.8315798956048372
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8832091620023609
#
# Cross-Val Testing Score: 0.8591562346368222
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8882875024100132
#
# Cross-Val Testing Score: 0.8680125976564652
#
# col_0      0   1
# Class
# 0      56857   7
# 1         29  69
# Validation Score: 0.8519792659607456
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8806732892120436
#
# Cross-Val Testing Score: 0.8578601531428672
#
# col_0      0   1
# Class
# 0      56858   6
# 1         33  65
# Validation Score: 0.8315798956048372
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8832091620023609
#
# Cross-Val Testing Score: 0.8616878802064425
#
# col_0      0   1
# Class
# 0      56858   6
# 1         31  67
# Validation Score: 0.8417839772374904
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8908233752003305
#
# Cross-Val Testing Score: 0.8718144624366
#
# col_0      0   1
# Class
# 0      56856   8
# 1         28  70
# Validation Score: 0.8570725138676742
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8794042536790487
#
# Cross-Val Testing Score: 0.8578645497135421
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8857472330683507
#
# Cross-Val Testing Score: 0.8604220574216324
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8920924107333253
#
# Cross-Val Testing Score: 0.8718372857898533
#
# col_0      0   1
# Class
# 0      56857   7
# 1         27  71
# Validation Score: 0.8621833475933987
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8806732892120436
#
# Cross-Val Testing Score: 0.8566127571406357
#
# col_0      0   1
# Class
# 0      56858   6
# 1         32  66
# Validation Score: 0.8366819364211638
#
#
#
#
#
# Max Depth: 5, Max Feature = 5, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.881940126469366
#
# Cross-Val Testing Score: 0.8604404842042109
#
# col_0      0   1
# Class
# 0      56858   6
# 1         31  67
# Validation Score: 0.8417839772374904
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8895543396673355
#
# Cross-Val Testing Score: 0.8730780869843962
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8933614462663203
#
# Cross-Val Testing Score: 0.8730965137669747
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8908233752003305
#
# Cross-Val Testing Score: 0.8730780869843962
#
# col_0      0   1
# Class
# 0      56859   5
# 1         29  69
# Validation Score: 0.8519968517795413
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8895543396673355
#
# Cross-Val Testing Score: 0.8705442431294385
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8933614462663203
#
# Cross-Val Testing Score: 0.8743969918316047
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8920924107333253
#
# Cross-Val Testing Score: 0.8743645348371223
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8920924107333253
#
# Cross-Val Testing Score: 0.8718100659142486
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8933614462663203
#
# Cross-Val Testing Score: 0.8756628146164147
#
# col_0      0   1
# Class
# 0      56858   6
# 1         29  69
# Validation Score: 0.8519880588701434
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8920924107333253
#
# Cross-Val Testing Score: 0.8743645348371223
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8920924107333253
#
# Cross-Val Testing Score: 0.8705508379854507
#
# col_0      0   1
# Class
# 0      56858   6
# 1         30  68
# Validation Score: 0.8468860180538169
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8946304817993151
#
# Cross-Val Testing Score: 0.8782010550420474
#
# col_0      0   1
# Class
# 0      56858   6
# 1         31  67
# Validation Score: 0.8417839772374904
#
#
#
#
#
# Max Depth: 5, Max Feature = 6, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8908233752003305
#
# Cross-Val Testing Score: 0.8743851599050384
#
# col_0      0   1
# Class
# 0      56859   5
# 1         30  68
# Validation Score: 0.8468948109632148
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 4
# Training Score: 0.8908233752003305
#
# Cross-Val Testing Score: 0.8769234002823472
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 4
# Training Score: 0.8959017156079827
#
# Cross-Val Testing Score: 0.87564658607085
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 4
# Training Score: 0.8959017156079827
#
# Cross-Val Testing Score: 0.8769168054746584
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 5
# Training Score: 0.8908189786489853
#
# Cross-Val Testing Score: 0.8756413490002959
#
# col_0      0   1
# Class
# 0      56858   6
# 1         27  71
# Validation Score: 0.8621921405027966
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 5
# Training Score: 0.8971707511409777
#
# Cross-Val Testing Score: 0.8756487843561874
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 5
# Training Score: 0.8971685528653051
#
# Cross-Val Testing Score: 0.8781848265448062
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 6
# Training Score: 0.8920902124576527
#
# Cross-Val Testing Score: 0.8769093700704435
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 6
# Training Score: 0.8946326800749878
#
# Cross-Val Testing Score: 0.8769168054263352
#
# col_0      0   1
# Class
# 0      56858   6
# 1         29  69
# Validation Score: 0.8519880588701434
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 6
# Training Score: 0.8959017156079827
#
# Cross-Val Testing Score: 0.8781826282594686
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 10, Random State = 1, Min Samples Split: 7
# Training Score: 0.8920902124576527
#
# Cross-Val Testing Score: 0.8769071717851062
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 50, Random State = 1, Min Samples Split: 7
# Training Score: 0.8946326800749878
#
# Cross-Val Testing Score: 0.8781804299258077
#
# col_0      0   1
# Class
# 0      56858   6
# 1         29  69
# Validation Score: 0.8519880588701434
#
#
#
#
#
# Max Depth: 5, Max Feature = 7, Number of Trees = 100, Random State = 1, Min Samples Split: 7
# Training Score: 0.8946326800749878
#
# Cross-Val Testing Score: 0.8794484510442787
#
# col_0      0   1
# Class
# 0      56858   6
# 1         28  70
# Validation Score: 0.85709009968647
#
#
#
#
#
# Best Run: {'Training Score': 0.89081897864898529, 'Cross-Val Testing Score': 0.87564134900029589, 'Validation Score': 0.86219214050279658, 'Max Depth': 5, 'Random State': 1, 'Max Feature': 7, 'Number of Trees': 10, 'Min Samples Split': 5}

# %% [markdown]
# As expected, random forest took the longest to run by far. I had to leave the computer running and come back to it multiple times to get through all the permutations of parameters. The best score using random forest was **0.862**, which was not as strong as the singular decision tree score of 0.867.

# %% [markdown]
# # Conclusion
#
# Looking deeper into our best performing model (the decision tree), we can see that we had a training score of 0.891 with a cross-validation testing score of 0.858. This shows that overfitting is present but not strong, which is good. The validation score shows how the model generalizes to unseen data, and returns a score of **0.867.** Of the 56,962 observations, 56927 of them were classified correctly. For the cross-validation testing set, 26 observations were labeled as false negatives (out of 98 true positives) and 9 were labeled as false positives (out of 56864 true negatives). This is a 99.98% accuracy rate for the true positives, which is the measure we care most about. This is paired with a 73% accuracy rate for true negatives, but this case is much more infrequent, and the consequences far less severe so overall there is a good balance between the two. Going forward, I would recommend further tuning the decision tree model to see if it can perform even better. Overall, I am happy with the final score of 0.867 and would feel confident recommending this model to a financial institution (or at least to my supervisor for review!)
